# %%
from pkg import *
from sct_fn import sct1

# %%
# ----- Spectroscopic - Photometric Redshift Relation ----- 

xlim = [0, 4]
ylim = [0, 4]

xtick = np.arange(0, 4, 0.5)
ytick = np.arange(0, 4, 0.5)

sct1('z_spec', 'z_peak', 'agn', 1, x_name = 'Spectroscopic Redshift', y_name = 'Photometric Redshift', xlim = xlim, ylim = ylim, xtick = xtick, ytick = ytick)

# %%
# ----- HR vs Redshift -----

xlim = [0, 6]
ylim = [-1, 1]

xtick = np.arange(0, 6, 1)
ytick = np.arange(-1, 1, 0.5)

sct1('z', 'HR', x_name = 'Redshift', y_name = 'Hardness Ratio', xlim = xlim, ylim = ylim, xtick = xtick, ytick = ytick, stats = True, var = 'HR')
# Out:
# Radio AGN: (HR = -1.51e-01, N = 15)
# H = 0.74 * S
#
# Overlapping Infrared/X-Ray AGN: (HR = -6.56e-02, N = 50)
# H = 0.88 * S
#
# Infrared AGN: (HR = -5.60e-02, N = 55)
# H = 0.89 * S
#
# X-Ray AGN: (HR = 5.84e-02, N = 281)
# H = 1.12 * S
#
# "True" SFG: (HR = 6.95e-02, N = 312)
# H = 1.15 * S
#
# "True" AGN: (HR = 1.16e-01, N = 73)
# H = 1.26 * S
#
# SFG: (HR = 1.43e-01, N = 98)
# H = 1.33 * S
